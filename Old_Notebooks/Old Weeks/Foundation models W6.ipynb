# %% [markdown]
# # Colab Notebook: Multimodal MIMIC-CXR (Images + Metadata)
# #   - Fusion from scratch: Concatenation & Cross-Attention
# #   - Foundation Model (MedCLIP) Adaptation: Linear, Partial FT, LoRA
# #   - Metrics: AUC, Accuracy, F1 (per class)

# %%
# !pip install -q pydicom
# !pip install -q timm==1.0.9 albumentations==1.2.1 torchmetrics==1.4.0.post0 scikit-learn==1.5.2 numpy==1.24 scipy==1.10 medclip==0.0.3 open_clip_torch peft transformers timm albumentations pandas jax jaxlib

import os, math, json, random, warnings
warnings.filterwarnings("ignore")
from typing import List
import numpy as np
import pandas as pd
from PIL import Image

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

import timm
import torchmetrics # Use torchmetrics instead of sklearn
from torch.cuda.amp import autocast, GradScaler

import albumentations as A
from albumentations.pytorch import ToTensorV2

import pydicom

try:
    from medclip import MedCLIPModel, MedCLIPVisionModelViT
    _HAS_MEDCLIP = True
except Exception:
    _HAS_MEDCLIP = False
try:
    import open_clip
    _HAS_OPENCLIP = True
except Exception:
    _HAS_OPENCLIP = True
from peft import LoraConfig, get_peft_model

SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", DEVICE)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 90.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Device: cuda

# %%
DATA_PATH = "./MIMIC-CXR"
# !mkdir -p {DATA_PATH}
# !wget https://uni-bonn.sciebo.de/s/YHuwFOg6q6sw1ZX/download -O {DATA_PATH}/MIMIC-CXR.zip
# !unzip {DATA_PATH}/MIMIC-CXR.zip -d {DATA_PATH}
# !curl -L --progress-bar https://uni-bonn.sciebo.de/s/XbomHCb6yL6nYN4/download -o ./radiomics.csv
# !curl -L --progress-bar https://uni-bonn.sciebo.de/s/e7fKPxDYcs83J67/download -o ./labels.csv

print("Data download complete.")
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18691393/56760870/a6698e16-f7a79eac-4fcf0ed1-88e88142-3abc8371.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18713249/57588311/4ffc60ec-ffd298d5-42243c1c-2ec47d75-64323bc4.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18713249/56117933/eb80ed86-da05e903-ac591a0e-e3cc826e-2a2c6ab9.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18991516/56755931/e68d876b-82b96bc4-73549fb3-144d8866-d5836ec5.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18871870/50832312/6744c4f1-d659b0de-9616f798-def4d319-7c248ea7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18871870/59153339/f3fcbda8-43ced708-1386efce-06910f23-abd0e1c3.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18871870/57448965/8e50972c-052a94b0-4c9a7a2a-ed550529-bf329b84.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18871870/52923609/a1ff3160-76069a6b-5ce15b1b-46564928-b7a3c300.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18176124/56025106/ee992ec0-7302f563-7011cc6a-76dec45d-cb2c2096.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18176124/56025106/0bf804e3-f5a5450c-d288158c-99ef00a3-a6c944c6.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18286113/57259501/3a7630ff-213ab95a-e6eb1088-09bf9813-34a23825.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18396451/53611967/43d3283e-420beb5c-dd6a0379-b7ad3b64-114ed1fc.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18396451/53365258/0da7a987-2a1639d6-01639eb6-e21eb9a2-ec70261b.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18344973/54498711/96f39b34-ec5c1ba4-6a3ed7a6-350140d4-3fdad7f0.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18344973/57699514/58207f08-3a1a0e6d-9204787f-acb3f3cd-fbe6da7d.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18344973/57699514/f5f75638-167fb2d4-79f3a2fa-dfe1dd01-cc8b2b80.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18595347/52760146/c07fd087-deeac90b-ddde0c2a-64daa046-8e821444.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18595347/52760146/475cc16e-655c1cb6-5dff3b08-8d90805a-2df81afe.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18802581/52074313/f607fade-18ad8f59-ce0f60ae-5204af72-246eb6c3.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18556519/53224144/00b29c61-7d2d0e19-1b5d52b2-d7d92bb8-c36196e2.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18556519/58198325/1b798eb4-aa173393-aecf2646-9ea2801b-6afdbd30.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18556519/58198325/edec566b-99f912e1-e45bce28-6f900823-fbfb66e0.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18556519/53586441/036c0783-7b9545e5-78f9b07a-8dcacd95-5f6adf10.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18417097/54985184/2309eaa7-baa24f61-9a66cb44-b3f489f0-e9a83f85.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18135875/59693944/b8885b7d-417fc055-e5f8bcc9-980342ee-8a883bc7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18096674/51162021/e03a8acf-6c4935df-d3a84111-8511dc75-f72b1402.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18096674/52134501/66e788cc-6c4c5d0a-e762969c-f2575a03-95d65a43.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18289735/52923109/66baa718-7a01670a-e71a15db-838567e0-d577565b.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18094547/57548436/87391c68-8b67a6e0-e4d6728b-2cab28f3-22eb73fd.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18094547/57548436/b60aa563-f55b20dc-393d8ad3-29ed0832-9c0c7d08.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18094547/51753178/663fef7d-5a34d871-797541f9-a1cf25fa-29c2192c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18094547/52666240/c639248b-a3455a98-4219341e-4b763e50-12d97e07.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18094547/51047727/52e5f19b-6dab9f2c-d244ca72-e33364a0-fd1d7104.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18094547/53382809/3fc0e312-3d8b074e-adcb91b2-957ced3d-749477f8.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18094547/53304299/6d272bc5-1078d8ff-c1ab991b-1d6c869e-6a56afad.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18094547/56689191/86e058f3-80788157-2bb4c57a-d878c2a4-2dd6b8b2.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18094547/59637299/c84c2136-625c7666-730e821c-b7ef48fa-135d7228.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18284218/54651869/48153cc7-48664b96-9cd7ecfb-0a1f187d-12761e9e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18358187/50759250/4051d22f-386d4f79-d9378ef4-9e7d8a03-83582602.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18776282/55561663/6f718d63-42ed3dc1-a77cdc06-dfe710b2-7b5d6f0c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18263872/52962715/30de31fd-563dede5-6765517b-3e978bff-022a680e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18263872/50412294/36eaed83-7651e3dc-c98c9179-7552c642-ab750f11.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18263872/50412294/281daefe-227aa1d0-51a864df-be90b6f8-bec2e680.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18263872/53235532/2e306542-f4a54535-3e7ce8bf-2d2baac6-f9357c76.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18319785/53901386/df74526d-fba70f15-9ba10c3a-651212a5-c2f33bcc.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18132095/50750588/0f09d6ce-08206362-7a618465-ee27f80a-bc38e649.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18400649/54554334/875bbbdf-61588d36-6509edb3-16555340-8e4c1a40.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18234943/54635918/b593a860-890bf75b-e5b2aca0-c6d023a3-5420a82d.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18884348/56046717/cabbaec4-4fd846c6-71dca6d9-ad630cfa-05c12f8c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18884348/57378657/97b6ab15-ac50fd7e-e9bca36f-f4c14cd8-211ebe6b.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18884348/53759181/eb56e94f-81ee63bb-ef2ad735-16d64967-d7cf421c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18743501/53528662/02145925-7ef7ac32-24e5172d-ee2e4ad4-bf06d545.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18743501/53104548/b91762f9-5f0f99b9-15a5bfd5-32fc3216-4a2a7718.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18925222/52755939/d89b7861-e4d884a3-582f0796-e72e9fe3-065d90be.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/54443454/9af2ee1f-1fd5a674-bfefd6d9-cc4b3d2c-83340266.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/54443454/e8bcdaf6-0b175829-2b87ed4e-960d22ae-5a316def.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/52567401/ef4dbb5d-f6405255-e3a1c128-ff6936eb-2d5bc72a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/54198542/255b1f95-3e6a97a3-e278c3e4-4c97f732-62eb2f1f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/58551658/13d2c71b-245c7875-55f08947-74f961d7-f049b970.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/55507412/e8684ac5-6242a79d-72e9f140-761f4ef4-138d8776.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/54505679/f37e03d0-e4b1df04-9c693484-5a8bc91c-1bda2096.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/55952611/0016482b-fda46447-dadb1d0e-a6d6fadd-4cc81e14.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/52794614/b49309e3-e49161e4-7cbdf82b-879ee255-a13c73fe.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/52708329/ca2d09f7-ba3168a6-964f97a2-60feb2f2-e8487245.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/57137010/3f63dd5f-e58e5a09-0e504e02-81eea34f-5c2c5f3a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/51659191/857c4657-42dd7153-ea23e105-e6fdd433-9dd00c5e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/52169276/a9c8b7fe-bb7a7c99-64b06f4f-40f50110-820f1ce6.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/59704742/48e92eac-06d69bee-4c164c16-286ebc0e-d7ea3e26.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/52577339/6593ac8a-894670fd-dd65a0dc-e537acdd-d9dc2ad4.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/55614632/f2574160-c3fe5bb9-b5e2a990-b0593400-afbeb608.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/56533157/1c2cfbe8-0f492a37-8d9e4718-4ee7255a-2a9774b7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/52550326/bfc22545-3a186dc9-86ec886e-2e10ac52-72fb6b6f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/57690087/e8be1781-0bf6b11f-9f6f01bf-9164d42e-df891fe8.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/57690087/c9f6a67d-3d9e24a1-0fe7a4fa-c1102b1e-94062a41.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/57759254/dd528a58-33d9c351-7c63c792-a5bcf5dc-88026b85.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/54846762/6a13b9d2-a1bb73de-5c2b6860-0fef50be-ed0ee4c6.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/54742731/f3d628c1-23e595f5-423afe07-b2437a8f-bd15dc1f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/50733674/28696149-ee49007d-6ae6f3cc-77a93fe3-ac06d655.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/50717471/4085a4f5-7928c2c6-5c451b04-fbf26f9c-4964d0ee.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/55436993/afbba4d1-cea3be3e-8b183658-c4b19553-442bdff2.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/55436993/12a9e93e-325c9f09-d3a1567e-a45ac7bd-103d0dbf.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/50721541/4ff535f7-5fdb1d58-7b50df02-d028207a-f1db11cb.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/50328321/0d124876-22624654-5a2663c0-9a55f0ca-a6a651c1.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/53846029/69e4daad-f8f28a7e-52774831-59c6999f-343d46b1.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/50161825/e11cb7a4-f69e4925-b5742ca8-e6b79d08-336b5141.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/50161825/5d8d9d09-717559e4-5f548845-248263fe-e608694a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/53704080/8e0ec35f-247a446d-dcf9ddcc-99b77521-49542e08.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/55137077/656d41b4-f93b91af-d511d24d-4db7f206-aba1c460.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/57547327/447707df-ad15c185-187bb04c-625178be-f1d663dd.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/51972743/aba2df7c-1d8f8841-f2c842cb-e1073323-fa85c2d5.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/55734469/be9a6653-b70de5e9-82fa2b88-c61048b8-8e1dcfa4.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/50252944/270086c0-7e8d7742-e57f5d8a-0bab1e98-3b9f0a7d.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/50252944/e4af99d4-fd1c05ba-2cc6e477-245da214-b328b647.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18990850/53506310/11b8bb1d-5f595c22-50ff7f07-f9ec0f9e-9fd1fc7c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18138794/55877390/90af84db-73dd2522-824ab393-477cf149-0907af77.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18193242/55799499/6366f148-fdb5986a-6a40e4d1-3591bb35-0757afcf.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18758372/52620158/25e68775-87021325-6da8c21f-50f2466c-8ad8c02f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18758372/57365033/f0b48387-ca761679-9dec7a6a-84661558-8818f516.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18758372/51243114/c5ee9e54-fe362b88-8d2f15c2-9c945055-598c9a5a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18574475/50757054/f99a120c-53caa577-395225ba-ff2c7f8c-8e193333.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18934359/57782612/28c60257-08cd8dc4-484fe701-93411f90-cc987a0f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18934359/57782612/c6f70023-0c1b11b6-4aedbc9e-79704598-44f56175.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18934359/57301835/d24b9202-a98cacf8-9d3a7a96-413145a2-96918c43.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18934359/57301835/58d88ec0-e05a0a36-9aa31872-1f63055c-463c6015.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18147209/59882063/7c4cefff-0ce2281d-9111effe-998feae8-5f0cba15.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18147209/57176117/473ef566-fd08c6ec-fa42c735-db5dea8a-a746bea8.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18415366/51443976/f41b8a45-1b49ebcd-d48f31c4-58e29b3f-f6d4a4dd.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/58974341/e5b3085b-f0248257-cb6b2c47-90f6d249-c512b749.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/58974341/0d22351a-5e66e575-c88d6a79-6986b28d-4385b2fa.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/58511785/9be135af-e763ad7a-ec519908-0d976b6e-b7d353a2.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/54817096/a58de4b2-94fc41b8-9da84619-8813b2f4-8ed19ef7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/58924398/7f14f7ba-de7a400f-f3034f4c-4891aadd-7cd62749.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/51241005/618bddb2-a014ad50-f655b1e3-0e84b831-f7751c95.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/50618554/18fa1b61-226eb609-8a9869ec-7e5d6c1c-d6d1da4f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/58250590/1f55d19c-aef1ac7b-84915707-566690b0-69eee32e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/58250590/e6902afa-99388d45-5d4b9215-83f5e718-85802fb4.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/54674373/c2f07698-8b08e1b7-fb9470f9-765f98b7-7a765eb0.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/54674373/414acf02-f96228b4-8abe90be-40f17658-7fdf199c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/50734942/90a06557-717b4645-306886f8-105c8977-f6b2464a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/52089500/77d8a956-d784efb1-688ba30e-1cdafe82-12521e80.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/54313721/f2a51f64-04a94d9f-862afb3a-9cf10139-2d6905e7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18874154/51257392/c4d9abc2-864dc1de-bc4bfea3-2a975163-16098f5a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18480948/56391877/9652e8e6-6b009f7f-b1a2aab3-662801d7-edfab5cc.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18504359/51661869/92801660-fd2e7be3-92eb099f-dd8cb570-83591c41.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18784957/54726484/0c637395-500fdf01-cc23748f-8732cf1a-ed3df057.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18002320/55349502/08d12001-c24231eb-27ebea6e-5a956510-64995172.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18002320/59014734/a4aee2a8-6b5293ce-ef6da89b-e50d98a0-f6d9dd8d.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18002320/51600161/c2f9fa1c-fd5048d8-6b1dd3fc-7968f98c-9b429b34.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18002320/54993044/e7ea4cdb-64ffd2eb-22f5c39a-b118f692-f7e3590e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18002320/54993044/9f362997-5dfb81f2-19747539-5540c715-7f775481.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18002320/50354967/a8e56eed-b1251649-5d9c80b8-6a26b987-14615a15.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18002320/58654762/2e686c2a-6e3dcb04-2eb0217f-084918a7-dad2fbff.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18002320/55848343/7ae483b7-b985c28c-6ce52b6d-1f68398a-8a9b0872.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18002320/55848343/9f594321-0d3b9c69-84a98677-59191723-254fd7e2.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18002320/56719219/1a2828f4-a8c044d7-72fdd12f-0705045d-b1891763.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18122493/50933090/9d531749-6fd57030-fbc1b513-77735571-3d945429.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18122493/51655443/df514f9e-7c2971cd-3468028a-f8843e97-fc5ca385.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18580802/57604271/cea3d234-9f6fe869-e7506981-59e8a443-480c4263.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18011159/58172505/096f0c15-da607bf0-2aed9a90-01fc7ae3-dd5dfaa3.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18011159/51092911/ebefe9a2-0670f66f-a039ac0c-bf35ffd2-1307d19c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18320255/54437314/bfb58ca3-42c1ea8a-9dc49b93-7dbd5d50-3a22ae41.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18320255/51034484/d7bf3072-8e67ebee-7a114c17-7d331034-88ba84c2.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18320255/58818478/ac4284af-6ec81f68-dc172ddb-d371a5be-c7b301fe.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18906866/51222745/f7663818-61d1f879-9ca75e99-80fada1e-6c0e8d6e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18906866/54988913/3b288064-d666a83a-26137bf7-cd2ffc40-b043344b.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18906866/53875202/105d14c0-4a362a25-e2776097-64fdb016-91239733.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18927749/54869161/798dee4e-b047da47-54f485e6-ed99979a-f96c9cea.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18456496/59161590/bc45cdc6-95749418-0eb5f724-68089e99-103db15c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18420240/51655908/7389ef62-3ed490de-e46b62b2-322f09fe-3808848f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18723421/57603237/5761dcc8-f2457099-9990b6be-9097ebbb-fdd3010b.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18723421/54810853/3f233fe5-9b94d584-701672fb-17e4794b-d40684c3.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18476866/58019757/c88ee08d-375079a5-d5e9c70c-13cb2928-78b5dcae.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18468160/50022530/389a2c05-5ebcbc3a-cc635f3e-c61b3277-e3a2b431.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18807203/56764851/fef64308-9fea5dff-c554faa7-b4a88a54-d211f97d.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18315945/51609374/488ebb53-6d5c84f6-8cf0d679-c949f6dc-188c3169.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18541916/53563397/c71b71d9-b26b5322-3d62ea25-78073bbc-204aa77c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18541916/52753356/74770766-cbe9a81b-f6ae6800-bfe0d72b-63c4d454.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18541916/50612139/ae746bdc-5526938a-27e6a560-ec8446c5-a37ae0c5.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18541916/51612469/04075de7-64ac5aba-b7ee1740-228b2d00-4e15d3ae.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18541916/55525529/de545bd7-9071e442-a9cf9f1c-9bb85eb7-437ed264.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18541916/58152100/f33e77d5-94b951e0-cae6f187-36e5034e-a4f3c191.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18541916/51143982/447ab876-2160decb-bfe69407-9ac972c2-56a0f05d.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18541916/53442787/962e162b-bbc2d0d9-a14a1a53-487fe1ed-6d3fab9e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18302118/57810846/e51f7d4c-016cfacb-b966b574-83aa9260-8c87f9d7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18302118/55357989/fce86f6e-ef5eedda-9601ccb5-a3ccb4f0-1551114f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18908915/54160283/ab901f60-6742c92a-98b993bd-723beded-18f7e9cc.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18908915/57671718/07cba158-fac2038f-497e639e-ebdbcbd8-b7f2e96e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18086091/54688241/b35838c4-4bd09bc8-70c19e87-d784ecc7-f368f081.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18086091/54688241/feccd3a2-10290512-7709fb0f-cee1619c-d26a425b.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18086091/59990529/3816bbc0-f6dbf1e9-b4003775-0d1c677f-22bf019c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18232062/58023530/0dda5129-7c030387-3c83d925-fae90635-d2f2c42f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18232062/58023530/735bb992-152c50c1-67ef7097-bc251ec3-ed657e35.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18678622/51227748/3cc775b9-4cbd2137-af0fea04-b1b74d33-a4e12dca.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18678622/50997720/2bd00de8-3f3b4a7d-9f77fa6f-70025dc6-3d3e0b79.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18678622/54199226/5561c42e-8d5aa0ed-e341b75f-0cd9fcd4-5848a512.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18678622/53012588/87446d07-86a50cf9-dd236e96-d4f7d853-19937601.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18570460/56817002/397912e7-2d61bd90-943f9088-8f287992-87ebefb4.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18834458/52380793/6cab75d0-898e718f-5e84af91-485ee0ef-ef159a90.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18834458/52380793/680ce0c8-46808748-b463b25f-ce78256f-c52c98d9.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18834458/59534793/e97b53c1-0d266da4-eac2fa9b-89b7af49-c9c2ca9e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18834458/59534793/8076796f-63f89ea7-6e61896a-19ee4dfe-1cc2a7c5.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18834458/52319262/fa7222a7-65007825-beab0c2c-8499dc95-c2bb8d00.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18834458/57866809/68655caa-f219c2bc-881d85ab-02fcb19f-8f468348.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18834458/57866809/dc89e7aa-83c76f53-9c5cbdff-41e89a6e-88de84d6.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18549982/57495473/e3e7c4cc-d4a2d463-295dc8fb-5525f5bc-a2d0c77a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18963843/56293224/092e0dfe-e30f1f7c-d983661d-3ee1ef7c-a1023eac.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18963843/56865520/a6ffe30d-720ae4a2-98c98054-71e022d8-76b3a234.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18883141/59367733/174e7ff6-8b307878-ed263712-2113d402-b97b5e05.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18883141/53489421/b7cfa2d9-bdb44477-e0ae68ce-2c299939-55649584.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18883141/56964450/506faef6-89a4a6e0-5ede1a0d-c3000f80-8678c48f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18883141/55612732/de7d85c9-b4d3955d-a5ead235-2368ac6d-280ce4f1.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18883141/57715859/70a2f14a-3cd732ac-efdf6b0a-3754896e-702095ba.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18883141/55531761/998d7ab0-aa52069b-34563af8-9ca9dbf5-6acec3ff.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18883141/57780481/fb94ea78-b42fb933-dfecc0c5-4ad3da31-81d66c08.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18883141/53814591/93b85272-ee950d6b-3ccc7bb4-9e221085-376b16a4.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18883141/54866133/d19d8ad3-20d009ec-ff75370e-823f9ffc-46d1d2a1.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18883141/55961531/b606b08c-49927670-78a4d5fc-cb660885-37a2907c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18883141/52586803/661cde99-358df935-3f6ee6ef-37d5a654-b880d906.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18883141/52586803/aa2fe996-ea917f45-c0c70718-c18a1681-ed2e1d32.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18883141/56026211/e0b83e4c-64bab28a-e620d11b-8de6b9c4-023cae6a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18166351/52269716/4ec0cfb1-416e6b24-fbf11a5b-b8639870-77369d99.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18595502/59676085/868fbc6d-3562949d-bbbb5013-6701f3d2-9a4ef10a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18191508/54175811/1b81a679-7bd4d1a7-7cf78b49-fd4f2fd4-991a7b9e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18191508/55116333/9019c6b3-f73e6f36-7e51ab83-30788859-bac64eb3.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18191508/52043194/5648e782-fe08fb6c-ca351322-dc95c1cb-a88ec84d.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18705300/52758179/6b68d54e-6fa7a055-b903dcb9-1b3039c2-a8c81a3e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/59278200/f84e4aca-b6f69795-c1d05728-c7e25f53-405d6e83.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/58360875/0fde9390-2ede0b5c-d8437f5d-29b746b1-35e6b4e7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/56491914/f6a3f6b7-d60706eb-b5b3f11e-98b6ca67-d72321d7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/59442461/abfcd881-bae1a3f7-0b1f601c-ead9d778-85d60a38.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/52968077/90228898-3077540a-83ca4851-ebf876f9-64a41ad9.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/55314044/89d45798-4e6e3094-4eca7160-5f08825f-cb72ec50.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/55314044/d6704884-ffc03c5a-d37b41f3-5a44b45e-ef32819b.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/56477454/14ff8a6f-1b6ac4c8-dfdbb0b1-39990e88-b4f8b24e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/54514442/d3ec6372-07074adf-d274af95-c81d6d29-f8f60ed6.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/54235032/eac6287b-54031160-56f5556c-2f150683-95ee7bc7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/54235032/aa9bd1ae-cce89f65-dc7308d7-7348e9be-8d3000eb.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/52666812/590838e7-c1d046c5-0863a0f4-8b266e8c-630903fb.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/50921961/19230b79-0c73094d-d2a7c1a3-371b6499-1c7253c3.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/52854002/50a224ef-4880d033-7e637b2e-ad1ca17f-0d14c965.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/52715243/a9a82343-4d4336db-a8c65aa5-a2a71d35-5af92851.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/55087221/d21e53ed-618c896d-4c71e031-2db8d662-aef3d0e8.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/57733597/252179c8-5a1ac200-ef821138-099543cd-c9eb6a2a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/58556177/1fc32dc1-576e9803-daef658d-4efade37-5b957b90.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/51666284/e765d838-a72ae9f8-6deec66d-881b5ea6-5f47065f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/55452261/ee1c1995-5d48ab47-3734c12c-048dfd3e-470073a7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/50187604/7bd0b606-1ec2a113-aaa64ee7-49f5b286-81fda319.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/50187604/a28398c2-29668c17-82ff1a4f-15480a98-b99280ee.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/56887689/ae28c67c-d986c8cf-1dfa817f-3ee55866-021807d0.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/55643091/0a23b5f3-77bca5ef-86f4365e-cae269b8-aa497f1a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/53646431/9214b85f-fd1dea8a-4859cbb8-2b5fb603-f6b69d0e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/52058396/a1b2bcd0-eb87a4ec-c0fcf6f4-49a932f7-a896dee7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/57036753/f994a423-6ed44595-be6ddf82-5bda81cb-a31fa181.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/54052941/6e8fb795-9ca9d6cf-a429779c-8b469ff2-787b22c8.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/54052941/c7310dc1-681f748e-97653239-9ddeba86-b9aa2814.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/59333889/f01922a2-d1890af3-bd575d08-de5cb0a6-27f11524.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/57358080/aff9186b-a41e5607-c2ca92f4-196a776a-aa56b08b.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/57924498/1a009084-f5dca500-c3c3b08e-7e36bfe5-fd9aa009.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/58627394/f52baaa8-55907427-90e32ae4-e2d204e8-784e404c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/54678887/d59941d1-1d3e670d-e53cf7b9-5b1add55-834f5a55.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/54678887/87a61aaa-5006910e-4c1d557d-a76af1d0-09cf1d30.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/50792648/b896d1a2-08d237b2-b10aa73c-d332a3f8-4c087db3.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/58755119/bb3efb99-35cd96d8-9cd9a23d-23cf4819-c8e2b1ea.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/57433034/710aa813-8bdb13d2-e2696ce9-ab230f92-f636349f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/59366651/1ab8a5c1-3f16c7e0-d4cfb755-6fd2cf36-623f0592.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/59765674/a6ccefef-8b3120b2-54dbce9c-b4b6668a-3aa31029.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/53299470/c3c4580f-c67afbea-7b34fca4-2244cbb0-d868cb29.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/55743338/2313889c-faee9825-b89b5723-e2cab712-5b001c99.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18031120/55533744/946511ed-d6b0bfa3-f91aa4bf-f4737844-3a847d98.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/53801638/9c443610-59f47563-872e8ff9-fdf0ec93-c4f283e4.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/52839965/073aa7bb-d936f9bb-bd5bdf5c-bed45446-550cf77f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/52839965/d4135c35-595d3fbd-c416fbd9-059e5e8e-7ef4e485.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/59010823/82456e29-435a09a4-f33999fa-525e3799-69535be2.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/53934068/8150d4fc-98948bf4-ac5edfff-ddd3adc3-abe1e6ff.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/55292350/9421cb2e-05bc1c20-9b25d64d-4717ff9a-83bc6890.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/57173043/7af64574-d4f86644-3b93e5ec-082f00ea-a15b81db.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/58701481/245f7b0e-e61508d8-391a18d0-48286c19-8d304660.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/58701481/4e1e59e6-b1f5de78-9917bbea-504099cb-b97a6e18.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/53804781/8f40228d-e3292cda-41c08e1d-eb1f2191-95653160.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/53804781/884bd17b-c197699b-b35c7843-9fb29735-a8b0bc00.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/56021965/ab88a133-4dc2621b-cbb112d4-5adb4eb0-15c1b1dc.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/58500519/02e836ae-fc29eb58-ddc50731-6affd80e-213da28a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/51446872/3eaad303-e57a13c1-d0c1f43e-ea64942a-06078544.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/56113756/2d2faa49-28356f2d-2b8c8235-6a5409e1-f827529a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/51786455/d4960bb8-06bfbb3e-3d09d27f-b762c530-d634af1f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/58749464/fe16b155-d1b38b6d-9f90a2ae-29c4cd92-651a5355.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/54266260/0c36f200-f5c52320-b0883114-7e97dd9e-51a10bbf.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/58413583/1d7d4675-8ae3a7a0-13feff38-a658854c-89f73ed4.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/54603697/a1555d4b-0df25cd0-73984a14-9d5b26c3-c6577e74.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/53203084/61b47523-c4f5ce5a-6cb6eab0-66c593f3-77aedb05.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/59198885/76b7cb7b-8f0f21d1-efee1ef7-a8f8efa6-47f5868b.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/55177093/5f62cd23-4d108cf6-d9987a61-18118de3-68d8d1a3.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/52092823/a9ae3202-c8a8cbb8-d59ba345-f75f61d0-2a2d0959.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/52523582/3f6276d4-2c35c750-ca8ed1f0-79992a6e-2e643af3.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/58517845/c39cc549-c6f51d0c-7624ead0-09acb1c6-b134db37.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/57937994/e6257346-97d670db-2e08bdc9-35b7606f-b9f4a3d5.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/51321828/6e3891ef-afa9d345-88496f7c-15428f72-07156b17.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/54911645/ddb39911-e33888c8-b1c78cb2-4b6b2543-9d4b4834.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/59275299/501feaef-b440f1ee-baf8a451-700ddfb6-36c7df38.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/52329601/276d9db4-bd29e518-46ee936e-6f751b75-8fbe7c55.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/59915380/b64c8e22-4d28b4d1-5ca4ab52-9ed728ed-63311ae7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/59785972/8ceba62c-8d2f253f-e80e1efa-8745099f-4ffe7b2c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/53357395/82a98123-7438c71a-49e210fb-a0c6e0b2-0f5d54db.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/51337026/6cfe823d-55edd2e4-f1c102db-f0134a6c-9b45ea39.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/51337026/28a7fb02-986ff8f0-8328542a-9830d882-4896e55a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/50081880/75138ed9-8375da41-c348de93-da8c47a2-b2fabb5c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18852216/56007336/96670005-9c6d5e2f-693a7180-2630f59a-5be7b096.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18229620/59856193/2c99c2aa-755ca059-ec25b0b9-fd834a7a-edf1e65a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18633146/54155517/bb868dcf-28602978-ce12f293-0fb9909b-925995f8.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18633146/50415626/365c7f81-8ce36651-1fafc9e7-4017e906-fc52a622.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18858348/58287308/f25c6146-5325c077-4104d47a-d048cb8e-5d73114c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18260419/55779703/019670a6-891a5b15-bf17f394-af899e36-b568dbf1.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18260419/50956045/b4e8b2af-70b823dc-49462658-7151049c-8331c482.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18513797/53532808/0f64ac9d-21ec456d-c9562a87-c8c96b05-e2aea905.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18266341/56854246/9338593c-8e962028-c528703f-d03ce0f8-bd98a204.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18648878/54849261/fcf56c9b-8fc89662-f88e8828-eca7f79f-f83f9844.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18614569/51084396/e15d6fc7-45be53f5-c87326ba-ccf05b96-d5d15aa2.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18614569/51084396/9e8e1669-b99ec40a-ad88747b-6ba39807-1c08dce1.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18614569/52137680/e4b75a85-af096fe3-e5a26974-1fcb913a-2d1121f1.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18237173/54504863/18dc0bb1-968327d4-a3981255-04931d09-94893a39.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18237173/54504863/d3735df3-ebb69087-a89ee296-049a3bc0-d7520def.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18237173/55699926/41f8287e-d204c978-5b5a2b9b-c8d545b3-e5a5bdcf.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18403013/53123649/eaf62684-945f07b7-18f4cbd0-c3cba2ef-15406744.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18403013/55084165/59c3c238-a5109ac6-1ebd05c1-89e1ee66-106dfb11.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18403013/51186714/35d5552c-1b23776b-ba774c23-4bac9749-67c4b614.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18403013/50485776/a6017a57-ac3a7b3f-3cc127e5-7c84d907-f5e8ef33.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18403013/57946858/04cb263c-2585c9ba-8aeffcc8-ab0d949d-1e137345.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18403013/55459363/5e81b0c7-aef50c80-36b37f67-19626526-28d8aad5.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18403013/52204776/6fa7e850-b899fce3-f493eeb6-5c32cc70-4b418a5e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18403013/58754363/266cdc9c-900daaad-1dc28660-fc1f7103-b316b39c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18403013/58614532/31c7acfa-7e074998-da4d5c78-426f1841-0af7ad98.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18403013/56466215/e5582aa3-ff180feb-b13fd1da-98c4c2f3-4c23c85a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18403013/54626188/305b6b88-dce94a2e-2f105aa3-453098d3-3d92d6a0.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18265366/56333255/81a5a23f-8539a117-3eae9021-265c74da-3506d9f8.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18130379/53298639/07ce8198-e7467842-509a7435-704e39d5-db11cb72.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18170454/55957580/2ae467f3-a4872966-4a0003b6-59d3614d-74a2841b.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18170454/55957580/c22c517e-226701c4-f5d1125f-63a7d2d1-1be10fbb.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18170454/59651822/a0440cd0-6c3d3269-6d46b703-601f8a18-c9d33622.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18170454/59651822/dc509127-e3e7a68f-e46b0118-4f612e0a-d56b9736.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18170454/51448972/00368b00-543b53d9-6ffc6ed9-cd5c95d4-e44bac70.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18943220/51154379/94ae1f3e-c1ac7589-548efd06-32a29dec-a1263304.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18943220/55151494/c59672f8-ed2eeb0f-ca05ed5c-522996ff-1afa17a0.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18504729/57450010/81805fab-16b732ef-51d9d136-ebef4030-950bd3a9.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18815345/57164244/fe8c2ddf-60b9a8ff-bbdd9e53-b29ebe2a-50e55ddc.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18815345/54426070/cfe00051-68ceed94-0802c558-f88affbb-b249e0ef.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18815345/59529023/d848c7ba-b4d4fb15-b0d1587f-e13ab74e-dd80853c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18815345/59529023/62a96834-0d66f2ee-b8811e4c-360d7585-d9671b83.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18855495/58332237/65fa66ef-c9c5280a-35c97a03-f0c1e682-51556292.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18855495/58332237/68d34787-e73a51d2-b509942e-0d6ccabf-0ca88739.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18855495/59335033/70f4e7a4-ec18ceed-0098a69b-b2fdbd0e-c035f0e9.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18320279/57533956/283cef81-a7f27eed-ae0ba0d9-4c3e0561-fb24b337.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18292152/52312894/ca289567-d3288dee-913f75af-485b445c-fd252bf5.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18292152/52312894/9938deab-7f7d1ec2-fe699187-e3f13787-fabe1b2a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18676319/56012237/f5effc3f-ea7e19d1-471d141b-635bd251-7c482653.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18172758/56729920/bb6afdf9-f8ddf890-d580e99f-7639e491-b34c6818.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18172758/57739060/704765e7-29706fea-a4eb5b04-059c30f5-f81dbdcf.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18172758/50006811/1d14c5d2-8b93abcd-a0e18747-60b0aae5-ea6bde50.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18172758/50006811/1cec008a-de9e0418-f3685c9b-8a24cc0e-dd342920.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18944208/54881172/cc5f9dd7-ebece152-18859f8e-27026b91-df81b284.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18944208/53492233/c9026f03-3da164e8-6264b236-9ae490aa-c3cef488.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966964/52328658/ff36f634-760bb4a1-c18a3e1d-b01f08f9-e24aed43.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966964/57795564/d80a0434-ab7c63b4-b8511ed0-bea5e7e6-1aa8ca7a.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966964/55399692/66de4fbb-4a4f3f03-6d6d4b41-67c3e583-1857b661.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966964/53008295/8d3dabf5-26f5573c-efa27018-bfe6ca39-c284e43f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966964/52912427/7d4af033-4dc06102-3344f673-0f08a459-614b2c17.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18230704/57560137/8260e6e3-df655786-1bcd13fc-4323c446-05dff4af.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18230704/57560137/8b6a6909-fa033893-af93e510-c2fab6ef-7d477035.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18550600/57643605/e2465184-2cc9991f-2c0b70ec-53fdf062-8d9047db.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18550600/59232545/fccb1d90-890309a6-408c9fac-9f384b1c-725d7197.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18450786/51007495/a124e959-0a392b38-c13f0a1c-7a1c12dd-7f20cc02.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18118373/51505176/0f87fda8-aae3ccd0-56c030d1-de5f3791-27121058.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18118373/56273820/ac52c883-e31d3944-c31c4d3a-eb89cc03-bcd381f2.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18118373/54967407/e4164e09-3a95fe93-7400f9b9-0f94000c-3979606c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18118373/54737911/d1621ef5-8704363f-e8f8c265-7e4c95d0-afdce742.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18118373/56543919/5e65593a-29767fd3-a0719992-9f51bbcb-f5a0d556.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18118373/53955923/81ab8bc1-f07e0f69-a4d42175-d0b9c82f-701e533f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18118373/56625067/5a3eb8fc-a9f7cf3b-5ff23212-7d2fa5c6-5ac70924.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18118373/55303564/0596aad2-e568766b-310de445-a67c0651-b0fabf2b.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18118373/50827419/277bb812-5fb727c3-c3bd8481-66f1a265-b7a54b59.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18118373/55508968/98950559-a7d46509-c507c99a-c0bea174-8f8bbe7f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18806799/54438441/892d27b6-51670748-673a638c-0541fe90-4d9d5401.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18806799/55428863/1e7516fe-1e5f1bcb-e2253d8c-a8bae7e4-b9909783.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18815342/57236797/52e9b617-7190021a-27a52bee-b8349ccd-5eb7b205.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18815342/59340103/383d9670-503bca1c-f6b5b120-bf043e96-1a64b2a7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18815342/59369293/b6b02ab2-fb7fa97d-ebf427a3-4ffb6e8c-4fea50a9.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18103393/55482277/1e0fe564-65f53840-2b5e4f2a-45d9aac5-7d84590e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18310249/53936518/face7a1d-04d58163-6dbcc90d-f10685e2-6a32a1d3.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18996381/53297879/519580bd-8d6f4969-4ccdcb93-c78d2046-21d0289f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18996381/53510266/456ef30d-160e8f84-9124c9d7-f8aedc48-a9c38882.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18996381/50698442/fd640b5a-74a8d334-8c19cc57-b17a3132-b48fdabc.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18996381/59216976/49c5c79b-d8debc99-7420fb80-1cb663ba-061e9242.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18996381/52744702/b850753c-0a78d4c1-5ac4acd3-b38b56dc-c046c239.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18481628/55719475/9536aae6-9168b0fe-49023cb4-8407b889-f637e625.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18481628/51608057/beb1dbbf-efd23b7c-407fb4a4-73c56b08-e74e6f1f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966399/50014483/ecc1bf52-fd1c6a72-6700281b-908524af-d4c698fc.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966399/53477024/c9bcfaef-cb5d1cbb-db036179-b18b7001-4622ba70.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966399/58648485/de79dd50-434f743c-279f7c21-a17fcc4c-1f19af40.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966399/55833978/18380b7f-1f242449-52c0a9ef-aa887b78-708d3a80.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966399/50437619/ece85ff4-2d620a8a-c5660d47-20dc869f-335754d9.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966399/55882409/1fa22f0f-7dcf2548-d9e209d8-654f5cab-253f4b6e.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966399/55772770/f7dfaa4c-9ecba3ce-eff072e7-c320af74-4935c3b3.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966399/55772770/070d2aeb-a3e1592d-9fa0ec26-37480097-932e5af4.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966399/52402237/c0b23b18-b1ee2080-e260f09b-e76aad0d-4fe06a0c.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966399/58385668/33de310c-3ba8f362-0f7ddb2a-94c49f81-f6cdd422.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18966399/52591564/a030102e-0c245dca-f868270d-b515c349-4be59578.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18227572/53417181/d4762c21-de01ed5d-eb8d002c-137db256-0f580d41.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18227572/53417181/c6874855-851f1b80-e91cc942-8d325ce2-99303ca1.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18227572/52207768/1dda5339-ebe092b4-321c4442-ed943ce7-34b80642.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18576755/53751116/6523b834-d6fa67db-e908316d-13f76e10-e259c791.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18576755/51198785/e0eded74-abab2ae5-5e726b98-8db767da-e4f09c0d.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18576755/57076580/a8b90a4c-a9315bb4-f7edce5d-b67a2583-ffc7487f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18576755/52943598/49168aa9-43144179-494f3c5b-5111d5fd-7c53fa07.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18433643/54349891/303a3a07-3f99b8ec-fa17d9fa-89c49171-4a3f567f.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18664811/54924786/a0f2a804-a7332177-ea338f16-5612db21-3ac54375.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18089887/58982031/a61dca5f-3dfa27eb-3d0f1e93-8f87a0e4-27a2fc98.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18089887/58209421/205074af-45f93170-1e7c3190-95e63636-fb43fd83.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18089887/59821186/729e6d3e-78df6639-67765796-9d90caf8-74c401b7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18089887/55544223/4b862857-f4273930-8bc9b0bd-a55c614c-111dc198.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18089887/50562255/b267186e-e9733162-1b54bdf8-1e108b7f-aaa2f965.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18089887/59563747/397e7e01-982384db-0e21bbce-7db693c7-001c56cd.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18089887/56032273/2112bc6e-5b16f218-82695e37-58b85e7f-e92112e4.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18089887/54332033/9bb6ff62-bfba43b7-33c2ab5a-32aec860-a2e347c3.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18527701/59770923/baf5771d-bab9d91d-11264f6b-95c061ee-11b5c181.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18679792/58171623/19fcf325-b2793c29-777dd2a1-57231e43-47501eab.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18709597/55511839/5bd7f51d-62a69770-6aa78cae-1e5bbb02-f1324034.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18818260/54175027/353a6c60-565589dd-3c88726a-a4321dcf-3be860b7.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18244848/57431275/3fe73e08-bb68ff0c-7c9eaf45-e4093b45-21052c53.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18648021/57833703/93318c78-1b671842-1af554f7-52f54a25-91a64acf.png
#   inflating: ./MIMIC-CXR/MIMIC-CXR/segmentation/18061894/55209280/50964a0d-2f5eac83-cf19ee16-55b0513d-22b8f58f.png
# ...
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18031120/s53646431/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18031120/s53646431/9214b85f-fd1dea8a-4859cbb8-2b5fb603-f6b69d0e.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18031120/s55643091/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18031120/s55643091/0a23b5f3-77bca5ef-86f4365e-cae269b8-aa497f1a.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18031120/s56887689/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18031120/s56887689/ae28c67c-d986c8cf-1dfa817f-3ee55866-021807d0.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18172758/s57739060/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18172758/s57739060/704765e7-29706fea-a4eb5b04-059c30f5-f81dbdcf.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18172758/s57739060/4c1288df-16664e19-318460d2-620758ec-e9498a68.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18172758/s56729920/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18172758/s56729920/bb6afdf9-f8ddf890-d580e99f-7639e491-b34c6818.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18172758/s50006811/1cec008a-de9e0418-f3685c9b-8a24cc0e-dd342920.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18172758/s50006811/1d14c5d2-8b93abcd-a0e18747-60b0aae5-ea6bde50.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18172758/s50006811/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18170454/s59651822/a0440cd0-6c3d3269-6d46b703-601f8a18-c9d33622.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18170454/s59651822/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18170454/s59651822/dc509127-e3e7a68f-e46b0118-4f612e0a-d56b9736.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18170454/s55957580/774f4dfc-fcfaf767-e7e6f50e-b398a73c-33777130.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18170454/s55957580/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18170454/s55957580/2ae467f3-a4872966-4a0003b6-59d3614d-74a2841b.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18170454/s55957580/c22c517e-226701c4-f5d1125f-63a7d2d1-1be10fbb.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18170454/s51448972/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18170454/s51448972/00368b00-543b53d9-6ffc6ed9-cd5c95d4-e44bac70.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18170454/s51448972/554f22e0-5e8d5817-9d775307-f665cdf7-6481f20b.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18170454/s51448972/d10eb060-a1d0bd78-318a425d-4d03fd67-6e9cd7bb.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18034251/s54636099/c77972dc-e420d762-13b79ea5-3b8963e3-fbf68845.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18034251/s54636099/1f094b06-9985d43a-c0b75c6a-b309540d-ba175726.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18034251/s54636099/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18034251/s54636099/dc4a3c8b-d5cf71e4-24c9cb56-6097019c-0b152eba.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18070922/s55309274/e243986c-82e6eb31-fc7d43d1-8d96f6f7-20f6faf6.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18070922/s55309274/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18070922/s55309274/f6fc50a4-80d17786-e3d68a2c-b04290d4-f4a80c7c.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18070922/s55309274/eb452b5b-195a75a1-20a06127-cd8d88a6-38216bb5.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18070922/s56742771/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18070922/s56742771/d95cc20b-59d4b2a7-2be90e8a-f486d41d-cea8fb0f.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18070922/s56742771/c91fc488-abc7c57f-f6141684-2efa6e2c-04d86a66.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18070922/s58669522/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18070922/s58669522/334d990b-79270607-18108d9b-f03cc9b2-f2af3b36.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18070922/s58669522/5e9c9093-f078bb8a-98611b2c-e9daf777-e45fae13.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18070922/s55619714/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18070922/s55619714/73d9fb6d-c69019d7-86696c18-a6ac5bb9-a754dc63.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18070922/s55619714/6ddb0f2f-d5f3292a-c98b6ae3-4a072fa9-05b24c43.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18070922/s55619714/e3723e7b-22017ecb-92553e43-41b3d538-fae00d91.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18019515/s54832461/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18019515/s54832461/071348f8-6ef54f12-8829b286-85a6c7eb-166cfd66.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18083580/s52882254/60329763-92b7b8f7-135ea9d6-7dabcb7b-b888902a.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18083580/s52882254/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18083580/s52882254/14f1e296-ab9f45dd-5737653d-93b168c2-bacf37a4.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s52122481/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s52122481/549e43f2-a94793cd-80f1c126-def76c6b-32a34495.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s53096482/b14cd17b-ca253869-cd309884-d5236895-17c87653.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s53096482/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s53096482/d6d4b43e-7f08b1ad-f9f21c87-2d342164-dd9be505.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s50611764/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s50611764/ce697c62-67fe25d7-947ad551-760de626-1b65d5b6.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s57954530/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s57954530/25666b79-df03ec58-28543f96-cbbcdc18-8cc2a05b.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s57954530/a18ceef8-b9ca2133-83be6e9c-aef3edf6-9651b09d.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s56434250/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s56434250/54ec7485-0891282c-2a24d9b7-14ab7d28-fb6d79dd.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s58662994/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s58662994/53f38941-22bb8b1e-188738a5-3e5c99a9-da5a8606.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s58662994/74836434-50906946-6a2360e1-f5a42a42-efe18105.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s54927200/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s54927200/02cfaa6e-5752cd71-9b975955-abc3fb48-7196e059.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052885/s54927200/49125e6d-d201aeb6-5442cfe5-099f02d3-4bc1f8b6.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18182144/s59342164/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18182144/s59342164/d4432473-15c0d817-de10b39f-8796956f-6283c68d.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18182144/s58230601/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18182144/s58230601/a8ab783d-0e80a305-2dab6e09-bed6e364-e309f9cc.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18182144/s58230601/0d273c3e-a45982d6-0d94582d-a15c8006-0a375e13.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18089076/s59661287/f25cd10b-4adc2252-138d25da-a0c4b1a8-d86d2005.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18089076/s59661287/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18089076/s59661287/5e9deac5-60379d8e-9ab80c17-6228873c-2a7a4a26.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18089076/s51930940/5f639c4f-1cf1bc2e-859dab7a-5bcb6205-542756a2.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18089076/s51930940/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18089076/s51930940/6e261724-4d1d424d-a0325091-6d7d41c4-60947034.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s52532534/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s52532534/19247334-b0656ac7-c60c1053-421daadf-d9ec6914.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s51239857/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s51239857/b83efffe-51263f63-e4563784-95648a62-478ac669.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s53302126/d219ce65-2ec104d6-56b59de5-2f37318c-43a63ad0.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s53302126/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s53302126/b8d3521f-08556327-15f546f6-520195b5-9f845ef9.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s53302126/01a1fbad-1a4d13ab-4bcdd66d-42e9367a-7e977c2a.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s55159460/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s55159460/9e193d76-fe4ab5fd-e0b740da-cde59c00-e46feec3.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s51438902/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s51438902/a89960c4-97dec2cb-6ae13afc-63027015-13217d26.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s51438902/9cef50ab-eaf6938b-67c91517-8d2d6d00-35eed5a8.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s52648242/fe42430c-5e8e8a3a-584d972f-d76e2ea0-fa0c94cc.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s52648242/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s52648242/08e2fce5-45616c1a-65c7b114-e3a7a3cd-6ef8205d.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s52648242/fdc1beb7-3fd8a6a2-b9c44b6e-bd8fefdd-a3761def.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s57007000/15f2275d-183b2935-37e45e89-d9875568-7bcb0b5b.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s57007000/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s57007000/c506bb81-09dc40bc-1650301e-e0a0bb0d-e80b7cfe.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s50577366/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s50577366/71316b58-a6524964-b7c80721-f01063e6-8f8c861c.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s50577366/4a9e16de-fea4a790-79984479-4ae09954-4252afb9.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s50577366/46832657-3814a832-38e37180-09a09102-9f88c5a0.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s56557601/3c9b39bc-a01a8f8a-3d75a74f-fd85f5fb-9cb3d4db.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s56557601/2ade2b54-0fbf1d07-8e92ea1d-5b53150b-9036963f.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s56557601/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s56557601/202828c6-e4684da6-ea549e61-f26cd0b1-637881fb.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s59630984/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s59630984/747df27f-bd4e3c64-35199e31-79fa1da0-50c11126.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18003081/s59630984/16a48f74-aa242b21-1a2f4487-9f22a088-3a09f471.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18015580/s51694813/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18015580/s51694813/2a7a96a4-eb12dca1-fa7fde5e-01cb7aa8-2da8654e.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18015580/s51694813/98e2bc97-615eae86-f3c4ac8a-753b6d3d-a8253def.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18015580/s51694813/28c74b94-01e02970-ad899436-46c96a02-de6959e0.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18015580/s51694813/af261208-03deffeb-fd8d00a9-c71da9b7-c16aefc0.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18015580/s54046140/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18015580/s54046140/29365293-67a72179-02496277-c14a54d4-5c148fd5.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18015580/s54046140/503ab3d3-b4dab6b1-199e3458-dc2e5442-bcc0d964.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18984616/s55967331/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18984616/s55967331/76b5a652-13d42eb1-2d7dec69-82761407-20ecd12f.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18984616/s55967331/5a77c3a2-d0f94e09-94eb621f-f66d487c-947ee67c.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18984616/s58877483/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18984616/s58877483/c634a832-7e512367-badf40b4-517e2ea1-6683444e.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18191958/s55663264/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18191958/s55663264/6a4e4e73-2c40dbe1-e309ce74-332adda8-df9980cd.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18191958/s55663264/bcfb5223-3f277889-f5206c35-c5fa1f7c-74e06278.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18191958/s56538787/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18191958/s56538787/f4c9f61d-c5fc74ef-c668550a-c48ff4cc-636313cd.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18191958/s56538787/86b7421a-3a07c208-fdb277b8-dd6f0bc3-877dcc1a.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18191958/s55557369/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18191958/s55557369/9f1a9a49-d373bf5b-3db0f3d4-a62bb250-07275451.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18191958/s55557369/f0ae1e93-01a2669b-165ab09e-c870b51a-d1551da2.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18178435/s53039992/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18178435/s53039992/1b4c2ee9-06587153-6805e52b-62814ecf-a11e9ef8.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18178435/s53039992/0c0e1cd7-02fd9e50-6068aa5e-f00a2bdb-e5105c69.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18178435/s59601335/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18178435/s59601335/d7dc2ae6-71f67589-cb17e774-8f4023b4-e7195472.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18178435/s59601335/e743da65-ec4c18fd-ded9e86f-2e509806-13a50527.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18004660/s57933749/47cf6ed5-b0aed197-cc300c2e-e891da05-230e77a1.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18004660/s57933749/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18004660/s56603719/d04b22e7-e15f1667-91923dfa-c47184af-a25f45b2.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18004660/s56603719/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18004660/s56603719/50ff90d3-437deb2b-bde2944c-f2d59335-0ebd47fa.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18004660/s56603719/6a4291e7-e47ef3e6-b82e20a7-403f4342-64e53265.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18004660/s56603719/bef57258-a6d10e02-16089ad6-258d7c38-67ec1d99.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18004660/s53299343/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18004660/s53299343/04c73c7f-a9881329-32a3cbbb-82906c8c-e039556a.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18004660/s54918333/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18004660/s54918333/8b0d00d5-0b783e8c-6c1667ea-cac79429-97ebb6c4.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18004660/s54918333/33578adb-e8c74b1e-af30ea17-f5c7e869-5ae7ca1b.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18004660/s58318628/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18004660/s58318628/475ce498-a2dca8ce-ea97f9e7-5baa00c3-ae44f66d.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052213/s59923490/index.html
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052213/s59923490/8b6386b3-44326c58-3d7c5a41-736e3a7b-bc594710.dcm
#   inflating: ./MIMIC-CXR/MIMIC-CXR/files/p18/p18052213/s59923490/bd1f917f-e49f1e29-19ae6b09-f203adbe-25964883.dcm
# ######################################################################## 100.0%
# ######################################################################## 100.0%
# Data download complete.

# %%
from sklearn.model_selection import train_test_split

radiomics = pd.read_csv("radiomics.csv")
labels_df = pd.read_csv("labels.csv")

# Merge on study_id instead of StudyInstanceUID
df = pd.merge(radiomics, labels_df, on="study_id", how="inner")

# Use dicom_id_y for path construction as StudyInstanceUID is not in merged df
df["path"] = df["dicom_id_y"].apply(lambda x: os.path.join(DATA_PATH, f"{x}.jpg"))
META_COLS = [c for c in df.columns if c.startswith("radiomics_") or c.startswith("feature_")]
label_cols = [c for c in labels_df.columns if c != "StudyInstanceUID"] # Keep this as is, refers to original labels_df cols
# Use study_id for splitting
uids = df["study_id"].unique()
train_ids, test_ids = train_test_split(uids, test_size=0.2, random_state=42)
val_ids, test_ids = train_test_split(test_ids, test_size=0.5, random_state=42)
def assign_split(uid):
    if uid in train_ids: return "train"
    elif uid in val_ids: return "val"
    else: return "test"
# Apply split based on study_id
df["split"] = df["study_id"].apply(assign_split)
df.to_csv("mimic_mmd.csv", index=False)
print("Saved merged dataset -> mimic_mmd.csv")
print(df["split"].value_counts())
# Out:
# Saved merged dataset -> mimic_mmd.csv
# split
# train    664
# val       81
# test      78
# Name: count, dtype: int64

# %%
CSV_PATH, OUTPUT_DIR = "./mimic_mmd.csv", "./outputs"
os.makedirs(OUTPUT_DIR, exist_ok=True)
IMG_SIZE, BATCH, EPOCHS_SCRATCH, EPOCHS_VLM = 256, 32, 5, 3

df = pd.read_csv(CSV_PATH)
import ast
import numpy as np

def parse_label_string(x):
    if isinstance(x, str):
        # Remove brackets, split by space, convert to float
        vals = [float(v) for v in x.replace('[','').replace(']','').split()]
        return np.array(vals, dtype=np.float32)
    elif isinstance(x, (list, np.ndarray)):
        return np.array(x, dtype=np.float32)
    else:
        return np.zeros(14, dtype=np.float32)  # fallback

df['labels_encoded_y'] = df['labels_encoded_y'].apply(parse_label_string)

DATA_PATH_IMAGES = "./MIMIC-CXR/MIMIC-CXR/"

LABELS = ['labels_encoded_y']
print("Using LABELS =", LABELS)

# Radiomics / meta feature columns
META_COLS = [c for c in df.columns if c.startswith("radiomics_") or c.startswith("feature_") or c.startswith("original_")]

train_meta = df[df["split"] == "train"][META_COLS].astype(np.float32)
META_MEAN, META_STD = train_meta.mean(0).values, (train_meta.std(0).values + 1e-6)

from torchvision import transforms

train_tfms = transforms.Compose([
    transforms.Resize(IMG_SIZE),
    transforms.RandomResizedCrop(IMG_SIZE, scale=(0.8, 1.0), ratio=(0.9, 1.1)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.3, contrast=0.3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
val_tfms = transforms.Compose([
    transforms.Resize(IMG_SIZE),
    transforms.CenterCrop(IMG_SIZE),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

class CXRDataset(Dataset):
    def __init__(self, frame: pd.DataFrame, split: str, labels: List[str], tfms):
        self.df = frame[frame["split"] == split].reset_index(drop=True)
        self.labels, self.tfms = labels, tfms

    def __len__(self):
        return len(self.df)

    def __getitem__(self, i):
        row = self.df.iloc[i]

        img_path = os.path.join(DATA_PATH_IMAGES, row["dicom_path"])
        try:
            dcm = pydicom.dcmread(img_path)
            img_array = dcm.pixel_array
            if img_array.ndim == 2:  # grayscale
                if img_array.dtype != np.uint8:
                    img_array = img_array.astype(np.float32)
                    img_array = (img_array - img_array.min()) / (img_array.max() - img_array.min()) * 255
                    img_array = img_array.astype(np.uint8)
                img = Image.fromarray(img_array).convert("RGB")
            elif img_array.ndim == 3 and img_array.shape[2] == 3:  # RGB
                if img_array.dtype != np.uint8:
                    img_array = img_array.astype(np.uint8)
                img = Image.fromarray(img_array)
            else:
                raise ValueError(f"Unsupported image format or dimensions: {img_array.shape}")
        except Exception as e:
            print(f"Error loading image {img_path}: {e}")
            raise e

        img_t = self.tfms(img)
        meta = (row[META_COLS].values.astype(np.float32) - META_MEAN) / META_STD

        label_field = row[self.labels[0]]
        y = np.array(label_field, dtype=np.float32)

        return img_t, torch.from_numpy(meta), torch.from_numpy(y)

# build datasets + loaders
train_ds, val_ds, test_ds = [
    CXRDataset(df, s, LABELS, t)
    for s, t in [("train", train_tfms), ("val", val_tfms), ("test", val_tfms)]
]
train_loader, val_loader, test_loader = [
    DataLoader(ds, batch_size=BATCH, shuffle=s, num_workers=2, pin_memory=True)
    for ds, s in [(train_ds, True), (val_ds, False), (test_ds, False)]
]

print(f"Splits -> train: {len(train_ds)} | val: {len(val_ds)} | test: {len(test_ds)}")
print("Labels:", LABELS)
print("Radiomics feature dims:", len(META_COLS))
# Out:
#   File "/tmp/ipython-input-2845365625.py", line 3
#     IMG_SIZE=224, BATCH, EPOCHS_SCRATCH, EPOCHS_VLM = 256, 32, 5, 3
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
def build_resnet(backbone="resnet50", pretrained=False, out_dim=1024):
    m = timm.create_model(backbone, pretrained=pretrained, num_classes=0, global_pool="")
    feat_dim = m.num_features
    projector = nn.Sequential(nn.AdaptiveAvgPool2d(1), nn.Flatten(), nn.Linear(feat_dim, out_dim), nn.ReLU(inplace=True))
    return m, projector, feat_dim

class ConcatFusion(nn.Module):
    def __init__(self, img_backbone="resnet50", img_dim=768, meta_in_dim=128, hidden=512, n_classes=2):
        super().__init__()
        self.cnn, self.proj, _ = build_resnet(img_backbone, pretrained=False, out_dim=img_dim)
        self.meta_proj = nn.Sequential(nn.Linear(meta_in_dim, 256), nn.ReLU(inplace=True))
        self.head = nn.Sequential(nn.Linear(img_dim + 256, hidden), nn.ReLU(inplace=True), nn.Linear(hidden, n_classes))
    def forward(self, x, meta):
        img_features = self.proj(self.cnn.forward_features(x))
        meta_features = self.meta_proj(meta)
        return self.head(torch.cat([img_features, meta_features], dim=1))

class CrossAttnFusion(nn.Module):
    def __init__(self, img_backbone="resnet50", token_dim=512, meta_in_dim=128, n_heads=8, n_layers=1, n_classes=2):
        super().__init__()
        self.cnn, _, fc = build_resnet(img_backbone, pretrained=False, out_dim=token_dim)
        self.token_proj, self.meta_proj = nn.Conv2d(fc, token_dim, kernel_size=1), nn.Linear(meta_in_dim, token_dim)
        self.cls = nn.Parameter(torch.zeros(1, 1, token_dim))
        enc_layer = nn.TransformerEncoderLayer(d_model=token_dim, nhead=n_heads, batch_first=True)
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=n_layers)
        self.head = nn.Linear(token_dim, n_classes)
        nn.init.normal_(self.cls, std=0.02)
    def forward(self, x, meta):
        feat = self.cnn.forward_features(x)
        tokens = self.token_proj(feat).flatten(2).transpose(1, 2)
        cls_token = self.cls.expand(tokens.shape[0], -1, -1)
        # Add metadata information to the CLS token
        cls_token = cls_token + self.meta_proj(meta).unsqueeze(1)
        tokens = torch.cat([cls_token, tokens], dim=1)
        # Get the output corresponding to the CLS token
        return self.head(self.encoder(tokens)[:, 0, :])

def count_trainable_params(m): return sum(p.numel() for p in m.parameters() if p.requires_grad)
print("Models defined.")
# Out:
# Models defined.

# %%
@torch.no_grad()
def evaluate(model, loader, labels):
    """
    Returns:
      {"per_label": {lab: {"AUC": float|nan, "F1": float, "ACC": float}},
       "macro": {"AUC": float|nan, "F1": float, "ACC": float}}
    """
    import numpy as np
    import torch
    from sklearn.metrics import roc_auc_score, f1_score, accuracy_score

    model.eval()
    all_logits, all_targets = [], []

    for batch in loader:
        # Support (imgs, meta, y) and (imgs, y)
        if len(batch) == 3:
            imgs, meta, y = batch
            imgs, meta, y = imgs.to(DEVICE), meta.to(DEVICE), y.to(DEVICE).float()
            logits = model(imgs, meta)
        else:
            imgs, y = batch
            imgs, y = imgs.to(DEVICE), y.to(DEVICE).float()
            logits = model(imgs)

        all_logits.append(logits.detach().cpu())
        all_targets.append(y.detach().cpu())

    logits = torch.cat(all_logits, dim=0).numpy()
    targets = torch.cat(all_targets, dim=0).numpy()
    probs = 1.0 / (1.0 + np.exp(-logits))           # sigmoid
    preds = (probs >= 0.5).astype(np.float32)

    per_label = {}
    aucs, f1s, accs = [], [], []
    for j, lab in enumerate(labels):
        y_true = targets[:, j].astype(int)
        y_prob = probs[:, j]
        y_pred = preds[:, j]

        # AUC needs both classes present
        if (y_true.max() == 0) or (y_true.min() == 1) or (y_true.sum() == 0) or (y_true.sum() == len(y_true)):
            auc = float("nan")
        else:
            try:
                auc = roc_auc_score(y_true, y_prob)
            except Exception:
                auc = float("nan")

        f1 = f1_score(y_true, y_pred, zero_division=0, average="binary" if len(np.unique(y_true)) == 2 else "macro")
        acc = accuracy_score(y_true, y_pred)
        per_label[lab] = {"AUC": float(auc), "F1": float(f1), "ACC": float(acc)}
        if not np.isnan(auc): aucs.append(auc)
        f1s.append(f1); accs.append(acc)

    macro_auc = float(np.mean(aucs)) if aucs else float("nan")
    macro_f1  = float(np.mean(f1s))
    macro_acc = float(np.mean(accs))
    return {"per_label": per_label, "macro": {"AUC": macro_auc, "F1": macro_f1, "ACC": macro_acc}}

# %%
batch = next(iter(train_loader))
print("Label shape:", batch[2].shape)
print("Label min/max:", batch[2].min().item(), batch[2].max().item())
# Out:
# Label shape: torch.Size([32, 14])
# Label min/max: 0.0 1.0

# %%
def train_model(model, train_loader, val_loader, labels, epochs=5, lr=1e-3, weight_decay=1e-4):
    import torch, numpy as np
    import torch.nn as nn

    criterion = nn.BCEWithLogitsLoss()
    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.AdamW(params, lr=lr, weight_decay=weight_decay)

    best = {"score": -1.0, "state": None}
    for ep in range(1, epochs + 1):
        model.train()
        running = 0.0
        for batch in train_loader:
            optimizer.zero_grad(set_to_none=True)
            if len(batch) == 3:
                imgs, meta, y = batch
                imgs, meta, y = imgs.to(DEVICE), meta.to(DEVICE), y.to(DEVICE).float()
                logits = model(imgs, meta)
            else:
                imgs, y = batch
                imgs, y = imgs.to(DEVICE), y.to(DEVICE).float()
                logits = model(imgs)

            loss = criterion(logits, y)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(params, max_norm=5.0)
            optimizer.step()
            running += loss.item() * y.size(0)

        val_metrics = evaluate(model, val_loader, labels)
        val_auc = val_metrics["macro"]["AUC"]
        print(f"[Epoch {ep}/{epochs}] train_loss={running/len(train_loader.dataset):.4f} | val_macro_auc={val_auc:.4f}")

        if (val_auc == val_auc) and (val_auc >= best["score"]):  # NaN-safe
            best["score"] = float(val_auc)
            best["state"] = {k: v.cpu() for k, v in model.state_dict().items()}

    if best["state"] is not None:
        model.load_state_dict(best["state"])
    return model, best

# %%
def count_trainable_params(m):
    return sum(p.numel() for p in m.parameters() if p.requires_grad)

class VLMWithHead(torch.nn.Module):
    def __init__(self, visual_backbone, feat_dim, meta_dim, n_classes, head_hidden=256):
        super().__init__()
        self.backbone = visual_backbone
        self.pool = torch.nn.AdaptiveAvgPool2d((1,1)) if hasattr(visual_backbone, "conv1") else None
        self.feat_dim = feat_dim
        self.head = torch.nn.Sequential(
            torch.nn.Linear(feat_dim + meta_dim, head_hidden),
            torch.nn.ReLU(inplace=True),
            torch.nn.Linear(head_hidden, n_classes),
        )

    def forward_visual(self, imgs):
        x = self.backbone(imgs)
        if isinstance(x, (tuple, list)):
            x = x[0]
        if x.ndim == 4:
            x = self.pool(x).flatten(1)
        return x

    def forward(self, imgs, meta):
        img_feat = self.forward_visual(imgs)
        return self.head(torch.cat([img_feat, meta], dim=1))

def build_openclip_visual(name="ViT-B-32", pretrained="laion2b_s34b_b79k"):
    import open_clip, torch
    import torch.nn.functional as F

    model, _, _ = open_clip.create_model_and_transforms(
        name, pretrained=pretrained, device=DEVICE
    )
    visual = model.visual

    if hasattr(visual, "positional_embedding"):
        pe = visual.positional_embedding  # [1, 1+N, C] or [1+N, C]
        if pe.ndim == 2:
            pe = pe.unsqueeze(0)  # make it [1, 1+N, C]

        patch = visual.patch_size[0] if isinstance(visual.patch_size, (tuple, list)) else int(visual.patch_size)
        target_hw = max(1, IMG_SIZE // patch)

        cls_pe = pe[:, :1]
        grid_pe = pe[:, 1:]  # [1, N, C]

        if hasattr(visual, "grid_size") and isinstance(visual.grid_size, (tuple, list)):
            old_h, old_w = visual.grid_size
        else:
            side = int(round(grid_pe.shape[1] ** 0.5))
            old_h, old_w = side, side

        old_tokens = old_h * old_w
        if grid_pe.shape[1] != old_tokens or (1 + target_hw * target_hw) != pe.shape[1]:
            print(f"Resizing positional embeddings from {1+grid_pe.shape[1]} → {1+target_hw*target_hw}")
            grid_pe = grid_pe[:, : old_h * old_w, :].reshape(1, old_h, old_w, -1).permute(0, 3, 1, 2)
            grid_pe = F.interpolate(grid_pe, size=(target_hw, target_hw), mode="bicubic", align_corners=False)
            grid_pe = grid_pe.permute(0, 2, 3, 1).reshape(1, target_hw * target_hw, -1)
            pe_new = torch.cat([cls_pe, grid_pe], dim=1)
            visual.positional_embedding = torch.nn.Parameter(pe_new)

    # ---- Feature dimension ----
    feat_dim = getattr(visual, "output_dim", None)
    if feat_dim is None:
        proj = getattr(visual, "proj", None)
        feat_dim = proj.shape[0] if isinstance(proj, torch.nn.Parameter) else 768

    return visual, feat_dim

class LoRALinear(torch.nn.Module):
    def __init__(self, base: torch.nn.Linear, r: int, alpha: int, dropout: float):
        super().__init__()
        self.in_features = base.in_features
        self.out_features = base.out_features
        self.r = r
        self.scaling = alpha / r
        self.weight = base.weight
        self.bias = base.bias
        # freeze the base weight & bias
        self.weight.requires_grad_(False)
        if self.bias is not None:
            self.bias.requires_grad_(False)

        self.lora_A = torch.nn.Parameter(torch.zeros(self.r, self.in_features))
        self.lora_B = torch.nn.Parameter(torch.zeros(self.out_features, self.r))
        torch.nn.init.kaiming_uniform_(self.lora_A, a=5**0.5)
        torch.nn.init.zeros_(self.lora_B)

        self.dropout = torch.nn.Dropout(dropout) if dropout and dropout > 0 else torch.nn.Identity()

    @classmethod
    def from_linear(cls, lin: torch.nn.Linear, r: int, alpha: int, dropout: float):
        m = cls(lin, r, alpha, dropout)
        return m

    def forward(self, x):
        # base
        y = torch.nn.functional.linear(x, self.weight, self.bias)
        # lora branch
        x_d = self.dropout(x)
        lora_update = torch.nn.functional.linear(
            torch.nn.functional.linear(x_d, self.lora_A),  # x @ A^T
            self.lora_B,                                  # (xA) @ B^T
        )
        return y + self.scaling * lora_update

def _gather_target_modules_for_lora(module):
    targets = []
    for name, sub in module.named_modules():
        if isinstance(sub, torch.nn.Linear):
            nm = name.lower()
            # target attention & proj-like linear layers
            if ("qkv" in nm) or (nm.endswith("proj")) or (".proj" in nm) or ("out_proj" in nm):
                targets.append(name)
    return targets

def apply_lora(module, r=8, alpha=16, dropout=0.05):
    to_replace = _gather_target_modules_for_lora(module)
    replaced = []
    for name in to_replace:
        parts = name.split(".")
        parent = module
        for p in parts[:-1]:
            parent = getattr(parent, p)
        leaf = parts[-1]
        old_lin = getattr(parent, leaf)
        if not isinstance(old_lin, torch.nn.Linear):
            continue
        new_lin = LoRALinear.from_linear(old_lin, r=r, alpha=alpha, dropout=dropout)

        device = old_lin.weight.device
        new_lin.lora_A = torch.nn.Parameter(new_lin.lora_A.to(device))
        new_lin.lora_B = torch.nn.Parameter(new_lin.lora_B.to(device))

        setattr(parent, leaf, new_lin)
        replaced.append(name)

    if not replaced:
        print("WARNING: No attention linear layers found for LoRA; proceeding without LoRA.")
    else:
        # freeze everything else
        for p in module.parameters():
            p.requires_grad_(False)
        for n, p in module.named_parameters():
            if n.endswith("lora_A") or n.endswith("lora_B"):
                p.requires_grad_(True)

        total = sum(p.numel() for p in module.parameters())
        trainable = sum(p.numel() for p in module.parameters() if p.requires_grad)
        pct = 100.0 * trainable / total if total else 0.0
        print(f"trainable params: {trainable:,} || all params: {total:,} || trainable%: {pct:.4f}")

    return module, replaced


def run_vlm_adaptation(mode="linear", epochs=3, lr=5e-4, lora_r=8):
    meta_dim = len(META_COLS)
    sample_labels = df['labels_encoded_y'].iloc[0]
    if isinstance(sample_labels, str):
        sample_labels = [float(v) for v in sample_labels.replace('[','').replace(']','').split()]
    n_classes = len(sample_labels)
    print("meta_dim =", meta_dim, "| n_classes =", n_classes)

    # Build OpenCLIP ViT visual encoder
    visual, feat_dim = build_openclip_visual()
    visual = visual.to(DEVICE)

    # Freeze by default
    for p in visual.parameters():
        p.requires_grad = False

    model = VLMWithHead(visual, feat_dim, meta_dim, n_classes, head_hidden=256).to(DEVICE)

    if mode == "linear":
        for p in model.backbone.parameters(): p.requires_grad = False
        for p in model.head.parameters(): p.requires_grad = True
        note = "linear probe (head only)"

    elif mode == "partial":
        # unfreeze last block(s) in ViT (simple heuristic)
        unfrozen = 0
        for n, m in model.backbone.named_modules():
            if ".blocks." in n and n.endswith(".mlp.fc2"):
                parent = model.backbone
                for part in n.split(".mlp.fc2")[0].split("."):
                    parent = getattr(parent, part)
                for p in parent.parameters(): p.requires_grad = True
                unfrozen += 1
        for p in model.head.parameters(): p.requires_grad = True
        note = f"partial tuning ({unfrozen} block(s)) + head"

    elif mode == "lora":
        model.backbone, targeted = apply_lora(model.backbone, r=lora_r, alpha=2*lora_r, dropout=0.05)
        for p in model.head.parameters(): p.requires_grad = True
        note = f"LoRA on attention ({len(targeted)} layers) + head"
    else:
        raise ValueError("mode must be one of: 'linear', 'partial', 'lora'")

    print(f"Trainable params: {count_trainable_params(model)} ← {note}")

    model, best = train_model(model, train_loader, val_loader, LABELS, epochs=epochs, lr=lr)
    test_metrics = evaluate(model, test_loader, LABELS)
    print("TEST macro:", test_metrics["macro"])
    return model, test_metrics, count_trainable_params(model)

# %%
meta_dim = len(META_COLS)
sample = df['labels_encoded_y'].iloc[0]
if isinstance(sample, str):
        sample = [float(v) for v in sample.replace('[','').replace(']','').split()]
n_classes = len(sample)

print(f"meta_dim = {meta_dim} | n_classes = {n_classes}")
print("--- Training ConcatFusion ---")
concat_model = ConcatFusion("resnet50", 768, meta_dim, 512, n_classes).to(DEVICE)
print("Trainable params:", count_trainable_params(concat_model))
concat_model, best_concat = train_model(
    concat_model, train_loader, val_loader, LABELS,
    epochs=EPOCHS_SCRATCH, lr=1e-3
)
concat_test = evaluate(concat_model, test_loader, LABELS)
print("\nConcatFusion TEST Results:")
print(json.dumps(concat_test["macro"], indent=2))
torch.save(
    {"state_dict": concat_model.state_dict()},
    os.path.join(OUTPUT_DIR, "concat_fusion_best.pt")
)

print("\n" + "="*40 + "\n")

print("--- Training CrossAttnFusion ---")
xattn_model = CrossAttnFusion("resnet50", 512, meta_dim, 8, 1, n_classes).to(DEVICE)
print("Trainable params:", count_trainable_params(xattn_model))
xattn_model, best_xattn = train_model(
    xattn_model, train_loader, val_loader, LABELS,
    epochs=EPOCHS_SCRATCH, lr=1e-3
)
xattn_test = evaluate(xattn_model, test_loader, LABELS)
print("\nCrossAttnFusion TEST Results:")
print(json.dumps(xattn_test["macro"], indent=2))
torch.save(
    {"state_dict": xattn_model.state_dict()},
    os.path.join(OUTPUT_DIR, "xattn_fusion_best.pt")
)
# Out:
# meta_dim = 93 | n_classes = 14
# --- Training ConcatFusion ---
# Trainable params: 25637710
# [Epoch 1/5] train_loss=0.3056 | val_macro_auc=0.6010
# [Epoch 2/5] train_loss=0.2378 | val_macro_auc=0.6707
# [Epoch 3/5] train_loss=0.2232 | val_macro_auc=0.7141
# [Epoch 4/5] train_loss=0.2160 | val_macro_auc=0.7192
# [Epoch 5/5] train_loss=0.2114 | val_macro_auc=0.7121
#
# ConcatFusion TEST Results:
# {
#   "AUC": 0.4411764705882353,
#   "F1": 0.0,
#   "ACC": 0.8589743589743589
# }
#
# ========================================
#
# --- Training CrossAttnFusion ---
# Trainable params: 27765326
# [Epoch 1/5] train_loss=0.2822 | val_macro_auc=0.6202
# [Epoch 2/5] train_loss=0.2449 | val_macro_auc=0.6364
# [Epoch 3/5] train_loss=0.2420 | val_macro_auc=0.6253
# [Epoch 4/5] train_loss=0.2436 | val_macro_auc=0.6141
# [Epoch 5/5] train_loss=0.2402 | val_macro_auc=0.6747
#
# CrossAttnFusion TEST Results:
# {
#   "AUC": 0.5397058823529413,
#   "F1": 0.0,
#   "ACC": 0.8717948717948718
# }

# %%
results_summary = []
for mode in ["linear", "partial", "lora"]:
    print("\n" + "="*12, mode.upper(), "="*12)
    vlm_model, test_mets, n_trainable = run_vlm_adaptation(
        mode=mode,
        epochs=EPOCHS_VLM,
        lr=(1e-3 if mode=="linear" else 5e-4),
        lora_r=8
    )
    results_summary.append({
        "model": f"openCLIP-ViT-B-32-{mode}",
        "trainable_params": n_trainable,
        "test_macro_auc": test_mets["macro"]["AUC"],
        "test_macro_f1":  test_mets["macro"]["F1"],
        "test_macro_acc": test_mets["macro"]["ACC"],
    })
    # Save the whole wrapped model (works for PEFT too)
    torch.save({"model_state": vlm_model.state_dict()},
               os.path.join(OUTPUT_DIR, f"vlm_{mode}_best.pt"))

import pandas as pd
df_results = pd.DataFrame(results_summary)
print(df_results)
# Out:
# ============ LINEAR ============
# meta_dim = 93 | n_classes = 14
# Resizing positional embeddings from 50 → 65
# Trainable params: 158734 ← linear probe (head only)
# [Epoch 1/3] train_loss=0.3529 | val_macro_auc=0.6242
# [Epoch 2/3] train_loss=0.2379 | val_macro_auc=0.6424
# [Epoch 3/3] train_loss=0.2260 | val_macro_auc=0.6364
# TEST macro: {'AUC': 0.5073529411764707, 'F1': 0.0, 'ACC': 0.8717948717948718}
#
# ============ PARTIAL ============
# meta_dim = 93 | n_classes = 14
# Resizing positional embeddings from 50 → 65
# Trainable params: 158734 ← partial tuning (0 block(s)) + head
# [Epoch 1/3] train_loss=0.4079 | val_macro_auc=0.6010
# [Epoch 2/3] train_loss=0.2459 | val_macro_auc=0.6162
# [Epoch 3/3] train_loss=0.2342 | val_macro_auc=0.6343
# TEST macro: {'AUC': 0.4955882352941176, 'F1': 0.0, 'ACC': 0.8717948717948718}
#
# ============ LORA ============
# meta_dim = 93 | n_classes = 14
# Resizing positional embeddings from 50 → 65
# trainable params: 516,096 || all params: 88,376,832 || trainable%: 0.5840
# Trainable params: 674830 ← LoRA on attention (24 layers) + head
# [Epoch 1/3] train_loss=0.3855 | val_macro_auc=0.6566
# [Epoch 2/3] train_loss=0.2401 | val_macro_auc=0.6475
# [Epoch 3/3] train_loss=0.2302 | val_macro_auc=0.6404
# TEST macro: {'AUC': 0.4852941176470588, 'F1': 0.0, 'ACC': 0.8717948717948718}
#                        model  trainable_params  test_macro_auc  test_macro_f1  \
# 0   openCLIP-ViT-B-32-linear            158734        0.507353            0.0
# 1  openCLIP-ViT-B-32-partial            158734        0.495588            0.0
# 2     openCLIP-ViT-B-32-lora            674830        0.485294            0.0
#
#    test_macro_acc
# 0        0.871795
# 1        0.871795
# 2        0.871795

# %%
summary_rows = [
    {"model": "ConcatFusion-ResNet50",
     "trainable_params": count_trainable_params(concat_model),
     "test_macro_auc": concat_test["macro"]["AUC"],
     "test_macro_f1":  concat_test["macro"]["F1"],
     "test_macro_acc": concat_test["macro"]["ACC"]},
    {"model": "XAttnFusion-ResNet50",
     "trainable_params": count_trainable_params(xattn_model),
     "test_macro_auc": xattn_test["macro"]["AUC"],
     "test_macro_f1":  xattn_test["macro"]["F1"],
     "test_macro_acc": xattn_test["macro"]["ACC"]},
]
summary_rows += results_summary

summary_df = pd.DataFrame(summary_rows)
summary_df.to_csv(os.path.join(OUTPUT_DIR, "summary_results.csv"), index=False)

print("\n" + "="*25 + " FINAL SUMMARY " + "="*25)
print(summary_df.to_string())
print(f"\nAll artifacts saved to: {OUTPUT_DIR}")
# Out:
# ========================= FINAL SUMMARY =========================
#                        model  trainable_params  test_macro_auc  test_macro_f1  test_macro_acc
# 0      ConcatFusion-ResNet50          25637710        0.441176            0.0        0.858974
# 1       XAttnFusion-ResNet50          27765326        0.539706            0.0        0.871795
# 2   openCLIP-ViT-B-32-linear            158734        0.507353            0.0        0.871795
# 3  openCLIP-ViT-B-32-partial            158734        0.495588            0.0        0.871795
# 4     openCLIP-ViT-B-32-lora            674830        0.485294            0.0        0.871795
#
# All artifacts saved to: ./outputs
